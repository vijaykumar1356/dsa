# %%
import requests
from pprint import pprint
import pandas as pd

API_KEY = 'MMFWJVVXM8YLCVHY'
with open('list-of-stocks-case-study.xlsx', 'rb') as stk_file:
    stk_df = pd.read_excel(stk_file, sheet_name='Sheet2', header=0)
    for stk_symbol in stk_df['SYMBOL'].head():
        url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={stk_symbol}.BSE&apikey={API_KEY}&outputsize=compact'
        r = requests.get(url)
        data = r.json()
        pprint(data)
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation '
#                   '(https://www.alphavantage.co/documentation/) for '
#                   'TIME_SERIES_DAILY_ADJUSTED.'}
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend '
#                                  'Events',
#                '2. Symbol': 'ADANIPORTS.BSE',
#                '3. Last Refreshed': '2022-11-16',
#                '4. Output Size': 'Compact',
#                '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2022-06-22': {'1. open': '687.8',
#                                         '2. high': '687.8',
#                                         '3. low': '665.55',
#                                         '4. close': '668.4',
#                                         '5. adjusted close': '663.8027',
#                                         '6. volume': '82915',
#                                         '7. dividend amount': '0.0000',
# ...
